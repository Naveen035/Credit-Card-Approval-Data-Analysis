# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv(r"C:\Users\jayas\Downloads\Ds Datasets\clean_dataset.csv")

# %%
df.head(1)
# Out:
#    Gender    Age  Debt  Married  BankCustomer     Industry Ethnicity  \
# 0       1  30.83   0.0        1             1  Industrials     White
#
#    YearsEmployed  PriorDefault  Employed  CreditScore  DriversLicense  \
# 0           1.25             1         1            1               0
#
#    Citizen  ZipCode  Income  Approved
# 0  ByBirth      202       0         1

# %%
df['Approved'].nunique()
# Out:
# 2

# %%
df.shape
# Out:
# (690, 16)

# %%
df.isnull().sum()
# Out:
# Gender            0
# Age               0
# Debt              0
# Married           0
# BankCustomer      0
# Industry          0
# Ethnicity         0
# YearsEmployed     0
# PriorDefault      0
# Employed          0
# CreditScore       0
# DriversLicense    0
# Citizen           0
# ZipCode           0
# Income            0
# Approved          0
# dtype: int64

# %%
plt.title('Credit Card Data Analysis')
vis = sns.catplot(data = df,x = 'Ethnicity',col = 'Gender',kind = 'count')

# %%
vis = sns.kdeplot(x = 'Employed',hue = 'Gender',data = df)

# %%
vis = sns.kdeplot(x = 'Approved',hue = 'Employed',data = df)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 690 entries, 0 to 689
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Gender          690 non-null    int64
#  1   Age             690 non-null    float64
#  2   Debt            690 non-null    float64
#  3   Married         690 non-null    int64
#  4   BankCustomer    690 non-null    int64
#  5   Industry        690 non-null    object
#  6   Ethnicity       690 non-null    object
#  7   YearsEmployed   690 non-null    float64
#  8   PriorDefault    690 non-null    int64
#  9   Employed        690 non-null    int64
#  10  CreditScore     690 non-null    int64
#  11  DriversLicense  690 non-null    int64
#  12  Citizen         690 non-null    object
#  13  ZipCode         690 non-null    int64
#  14  Income          690 non-null    int64
#  15  Approved        690 non-null    int64
# dtypes: float64(3), int64(10), object(3)
# memory usage: 86.4+ KB

# %%
df['Industry'] = df['Industry'].astype('category')
df['Ethnicity'] = df['Ethnicity'].astype('category')
df['Citizen'] = df['Citizen'].astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 690 entries, 0 to 689
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Gender          690 non-null    int64
#  1   Age             690 non-null    float64
#  2   Debt            690 non-null    float64
#  3   Married         690 non-null    int64
#  4   BankCustomer    690 non-null    int64
#  5   Industry        690 non-null    category
#  6   Ethnicity       690 non-null    category
#  7   YearsEmployed   690 non-null    float64
#  8   PriorDefault    690 non-null    int64
#  9   Employed        690 non-null    int64
#  10  CreditScore     690 non-null    int64
#  11  DriversLicense  690 non-null    int64
#  12  Citizen         690 non-null    category
#  13  ZipCode         690 non-null    int64
#  14  Income          690 non-null    int64
#  15  Approved        690 non-null    int64
# dtypes: category(3), float64(3), int64(10)
# ...

# %%
df1 = df[['Gender','Age','Debt','Married','BankCustomer','YearsEmployed','PriorDefault','Employed','CreditScore','DriversLicense','ZipCode','Income','Approved']]

# %%
plt.figure(figsize=(10,10))
vis = sns.heatmap(df1.corr(),annot=True,square=True,linecolor='White',fmt = '-.2f')
plt.savefig('vis4.png')

# %%
plt.title('Credit Card Data Analysis')
vis = sns.catplot(data = df,x = 'Industry',col = 'Gender',kind = 'count',palette = 'Set2')

# %%
plt.title('Credit Card Data Analysis')
vis = sns.boxplot(data = df,y = 'Industry',x = 'Ethnicity',palette = 'Set2')
vis = sns.stripplot(data = df,y = 'Industry',x = 'Ethnicity',jitter = 0.001,palette = 'Set3')

# %%
plt.title('Credit Card Data Analysis')
vis = sns.distplot(df['CreditScore'],bins = 12)

# %%
plt.figure(figsize=(10,10))
plt.title('Credit Card Data Analysis')
vis = sns.jointplot(x = 'CreditScore',y = 'Debt',data = df,hue = 'Gender')

# %%
plt.figure(figsize=(10,10))
vis = sns.violinplot(y = 'Industry',data = df,hue = 'Ethnicity')
plt.savefig('vis9.png')

# %%
vis = sns.kdeplot(x = 'YearsEmployed',data = df,hue = 'Gender')

# %%
plt.title('Credit Card Data Analysis')
plt.figure(figsize=(8,8))
plt.subplot(2,2,1)
vis = sns.kdeplot(x = 'YearsEmployed',data = df,hue = 'Gender')
plt.subplot(2,2,2)
vis = sns.countplot(x = 'Ethnicity',data = df)
plt.subplot(2,2,3)
vis = sns.violinplot(y = 'BankCustomer',x = 'Gender',data = df)
plt.subplot(2,2,4)
vis = sns.distplot(df['CreditScore'],bins = 10)

# %%
vis = df.plot.area(y = ['YearsEmployed','CreditScore','Approved','Debt'],alpha = 0.4,figsize = (10,10))
plt.savefig('vis12.png')

# %%
df2 = df[['YearsEmployed','CreditScore','Approved','Debt','Married','BankCustomer',]]

# %%
vis = sns.pairplot(data = df2,hue = 'Approved',kind = 'scatter')
plt.savefig('vis13.png')
